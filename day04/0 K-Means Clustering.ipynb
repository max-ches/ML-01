# %% [markdown]
# # K-Means Clustering

# %% [markdown]
# # Unsupervised Learning 이다.

# %% [markdown]
# ### 레이블 데이터가 없다.

# %% [markdown]
# ### 예) 우리가 가지고 있는 고객 데이터를 가지고, 고객 부류를 나누고 싶다. => 클러스터링

# %% [markdown]
# # K-Means Slustering

# %% [markdown]
# ## k 개의 그룹을 만든다. 즉, 비슷한 특징을 갖는 것들끼리 묶는것

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline

# %% [markdown]
# ### Importing the dataset
#
# Mall_Customers.csv

# %%
# 4번째와 5번쨰 컬럼만 사용하겠다. 
X =

# %%
# 3개 그룹으로 클러스터링 해달라고 한번 해보자.

# %%
# 위처럼, 그룹의 갯수를 맘데로 쓰면 안된다.
# WCSS 값을 찾아서, 최적의 그룹의 갯수를 먼저 파악한 후에
# 그 그룹갯수로 학습해서 그루핑 정보를 얻어온다.

# %%
# 이제 그래프로 전체 분포 먼저 보자

# %%
# 클러스터링 정보 포함하여 Visualising 한다.

# %%
# 문제1. 그룹이 3인 사람들 데이터 가져오시오.

# %%
# 문제2. 그룹별 수입 평균을 보여주세요.

# %%
# 문제3. Group별 소비지표를 나타내되, 평균값과 최대값 두개를 보여주세요.
